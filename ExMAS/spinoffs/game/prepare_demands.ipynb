# %% [markdown]
# ## ExMAS
# > Equilibrium matching - expieriments for the paper
#
# ---

# %%
import os
import numpy as np
import pandas as pd
cwd = os.getcwd()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.display import display
pd.options.display.max_columns = None

# %%
os.chdir(os.path.join(cwd,'../../..'))
import ExMAS.main
import ExMAS.utils
from ExMAS.utils import inData as inData

# %% [markdown]
# ### 1. __Toy__

# %%
params = ExMAS.utils.get_config('ExMAS/spinoffs/game/game_small_sparse.json') # load the default

# %%
inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the graph

# %%
params.city = 'Nootdorp, Netherlands'
params.logger_level = 'WARNING'
params.shared_discount = 0.4
params.simTime = 0.05
params.nP = 10
params.matching_obj = 'u_pax'
params = ExMAS.utils.make_paths(params)
params.t0 = '17:00'
ExMAS.utils.save_config(params,'ExMAS/spinoffs/game/game_toy.json')
params.t0 = pd.to_datetime(params.t0)

# %%
inData = ExMAS.utils.generate_demand(inData, params)
inData.requests.to_csv('ExMAS/spinoffs/game/toy.csv')

# %%
ExMAS.utils.plot_demand(inData, params)

# %% [markdown]
# ### 1. Small sparse

# %%
params.city = 'Nootdorp, Netherlands'
params.logger_level = 'WARNING'
params.shared_discount = 0.4
params.simTime = 0.5
params.nP = 100
params.matching_obj = 'u_pax'
params = ExMAS.utils.make_paths(params)
params.t0 = '17:00'
ExMAS.utils.save_config(params,'ExMAS/spinoffs/game/game_small_sparse.json')
params.t0 = pd.to_datetime(params.t0)

# %%
inData = ExMAS.utils.generate_demand(inData, params)
inData.requests.to_csv('ExMAS/spinoffs/game/small_sparse.csv')

# %%
ExMAS.utils.plot_demand(inData, params)

# %%
ExMAS.utils.plot_demand(inData, params)

# %% [markdown]
# ---
# (c) Rafał Kucharski, Delft, 2020
