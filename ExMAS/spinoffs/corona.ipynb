# %%
import os
cwd = os.getcwd()

# %%
os.chdir(os.path.join(cwd,'../..'))
import ExMAS.main
import ExMAS.utils
import ExMAS.corona

# %%
from ExMAS.utils import inData as inData

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
pd.options.display.float_format = '{:.3f}'.format
import numpy as np
from math import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import json
from scipy.stats import *


import pprint

# %%
plt.rcParams['figure.figsize'] = [16, 4]
plt.rcParams["font.family"] = "Helvetica"
plt.style.use('ggplot')
colors = sns.color_palette("muted")

# %%
2000*0.04
# Out:
# 80.0

# %%
params.city = 'Amsterdam, Netherlands'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2aacbe3eb3b0> in <module>
# ----> 1 params.city = 'Amsterdam, Netherlands'
#
# NameError: name 'params' is not defined

# %%
pprint.pprint(params)
# Out:
# {'PT_discount': DotMap(),
#  'VoT': 0.0035,
#  'WtS': 1.3,
#  'avg_speed': 8,
#  'city': 'Amsterdam, Netherlands',
#  'corona': {'big': True,
#             'infected_prior': 0,
#             'initial_share': 0.1,
#             'one': False,
#             'p': 0.3,
#             'participation': 0.625,
#             'participation_prob': 0.8,
#             'recovery': 14,
#             'time_threshold': 60,
#             'time_to_quarantine': 7},
#  'delay_value': 1,
#  'demand_structure': {'destinations_dispertion': -0.001,
#                       'origins_dispertion': -0.0003,
#                       'temporal_dispertion': 0.3,
#                       'temporal_distribution': 'uniform'},
#  'dist_threshold': 100000,
#  'horizon': 1200,
#  'just_init': True,
#  'matching_obj': 'u_veh',
#  'max_degree': 8,
#  'multi_platform_matching': True,
#  'nP': 320,
#  'p': 0.8,
#  'participation': 0.5,
#  'paths': {'G': 'ExMAS/data/graphs/Amsterdam.graphml',
#            'albatross': 'ExMAS/data/albatross',
#            'data': 'ExMAS/data',
#            'main': 'ExMAS',
#            'params': 'ExMAS/data/configs',
#            'postcodes': 'ExMAS/data/postcodes/PC4_Nederland_2015.shp',
#            'skim': 'ExMAS/data/graphs/Amsterdam.csv'},
#  'pax_delay': 15,
#  'plot': DotMap(),
#  'prep_only': True,
#  'price': 1.5,
#  'profitability': False,
#  'report': True,
#  'shared_discount': 0.3,
#  'simTime': 4,
#  't0': Timestamp('2020-07-17 14:51:37.469081'),
#  'use_prep': False,
#  'without_matching': True}

# %% [markdown]
# ---
# params

# %%
params = ExMAS.utils.get_config('ExMAS/data/configs/corona.json')  # configuration, including shareability parameters (to reproduce utility)
params.nP = 320
params.simTime = 4
params.city = 'Amsterdam, Netherlands'
params.corona.initial_share = 0.1  # initial probability of being infected
params.corona.time_threshold = 60  # minimal time of travelling together to infect
params.corona.infected_prior = 0  # minimal time of travelling together to infect
params.corona.time_to_quarantine = 7  # minimal time of travelling together to infect
params.corona.participation = 0.625
params.max_degree = 4
params.pax_delay = 30
params.shared_discount = 0.25
params.corona.p = 0.8
params.report = True
params.use_prep = False
params.prep_only = True
params.corona.recovery = 14
params.multi_platform_matching = True
params.without_matching = True
params.corona.one = False
params.corona.big = True  # small set of 300 trips to test and big of 3000 for proper experiments

# %%
params.t0 = '15:00'
params = ExMAS.utils.make_paths(params)
ExMAS.utils.save_config(params, path = 'ExMAS/data/configs/corona.json')

# %%
params.corona.p = 0.3
ExMAS.corona.pipe(inData, params)
# Out:
# 17-07-20 14:52:28-INFO-Initializing pairwise trip shareability between 320 and 320 trips.
# 17-07-20 14:52:28-INFO-creating combinations
# 17-07-20 14:52:28-INFO-102080	 nR*(nR-1)
# 17-07-20 14:52:30-INFO-Reduction of feasible pairs by 99.71%
# 17-07-20 14:52:30-INFO-Degree 2 	Completed
# 17-07-20 14:52:31-INFO-trips to extend at degree 2 : 619
# 17-07-20 14:52:31-INFO-At degree 2 feasible extensions found out of 44 searched
# 17-07-20 14:52:31-INFO-Degree 3 	Completed
# 17-07-20 14:52:31-INFO-trips to extend at degree 3 : 44
# 17-07-20 14:52:31-INFO-At degree 3 feasible extensions found out of 1 searched
# 17-07-20 14:52:31-INFO-Degree 4 	Completed
# 17-07-20 14:52:31-INFO-trips to extend at degree 4 : 1
# 17-07-20 14:52:31-INFO-At degree 4 feasible extensions found out of 0 searched
# 17-07-20 14:52:31-INFO-Degree 5 	Completed
# 17-07-20 14:52:31-INFO-No more trips to exted at degree 5

# %%
params.prep_only = False
params.use_prep = True
ExMAS.corona.pipe(inData, params)
ExMAS.corona.plot_spread(inData)
# Out:
# 17-07-20 14:45:01-INFO-day 1
# 17-07-20 14:45:01-INFO-recovered 0
# 17-07-20 14:45:02-INFO-Matching 200 trips to 334 rides in order to minimize u_veh
# 17-07-20 14:45:02-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,498
# reduced by matching to:               60,591
# 17-07-20 14:45:02-INFO-Day: 1	, quarantined: 0	 active today: 200.
# 17-07-20 14:45:03-INFO-state
# I     32
# S    288
# dtype: int64
# 17-07-20 14:45:03-INFO-day 2
# 17-07-20 14:45:03-INFO-recovered 0
# 17-07-20 14:45:03-INFO-Matching 200 trips to 338 rides in order to minimize u_veh
# 17-07-20 14:45:04-INFO-Problem solution: Optimal.
# Total costs for single trips:         66,042
# reduced by matching to:               61,626
# 17-07-20 14:45:04-INFO-Day: 2	, quarantined: 0	 active today: 200.
# 17-07-20 14:45:04-INFO-state
# I     34
# S    286
# dtype: int64
# 17-07-20 14:45:04-INFO-day 3
# 17-07-20 14:45:04-INFO-recovered 0
# 17-07-20 14:45:05-INFO-Matching 200 trips to 344 rides in order to minimize u_veh
# 17-07-20 14:45:05-INFO-Problem solution: Optimal.
# Total costs for single trips:         66,799
# reduced by matching to:               62,770
# 17-07-20 14:45:05-INFO-Day: 3	, quarantined: 0	 active today: 200.
# 17-07-20 14:45:06-INFO-state
# I     34
# S    286
# dtype: int64
# 17-07-20 14:45:06-INFO-day 4
# 17-07-20 14:45:06-INFO-recovered 0
# 17-07-20 14:45:07-INFO-Matching 200 trips to 340 rides in order to minimize u_veh
# 17-07-20 14:45:07-INFO-Problem solution: Optimal.
# Total costs for single trips:         66,529
# reduced by matching to:               62,081
# 17-07-20 14:45:07-INFO-Day: 4	, quarantined: 0	 active today: 200.
# 17-07-20 14:45:08-INFO-state
# I     34
# S    286
# dtype: int64
# 17-07-20 14:45:08-INFO-day 5
# 17-07-20 14:45:08-INFO-recovered 0
# 17-07-20 14:45:08-INFO-Matching 200 trips to 345 rides in order to minimize u_veh
# 17-07-20 14:45:08-INFO-Problem solution: Optimal.
# Total costs for single trips:         66,195
# reduced by matching to:               61,319
# 17-07-20 14:45:09-INFO-Day: 5	, quarantined: 0	 active today: 200.
# 17-07-20 14:45:09-INFO-state
# I     34
# S    286
# dtype: int64
# 17-07-20 14:45:09-INFO-day 6
# 17-07-20 14:45:09-INFO-recovered 0
# 17-07-20 14:45:10-INFO-Matching 200 trips to 344 rides in order to minimize u_veh
# 17-07-20 14:45:10-INFO-Problem solution: Optimal.
# Total costs for single trips:         67,396
# reduced by matching to:               62,827
# 17-07-20 14:45:10-INFO-Day: 6	, quarantined: 26	 active today: 200.
# 17-07-20 14:45:11-INFO-state
# I     13
# Q     21
# S    286
# dtype: int64
# 17-07-20 14:45:11-INFO-day 7
# 17-07-20 14:45:11-INFO-recovered 0
# 17-07-20 14:45:12-INFO-Matching 189 trips to 322 rides in order to minimize u_veh
# 17-07-20 14:45:12-INFO-Problem solution: Optimal.
# Total costs for single trips:         61,979
# reduced by matching to:               57,536
# 17-07-20 14:45:12-INFO-Day: 7	, quarantined: 21	 active today: 189.
# 17-07-20 14:45:13-INFO-state
# I     15
# Q     21
# S    284
# dtype: int64
# 17-07-20 14:45:13-INFO-day 8
# 17-07-20 14:45:13-INFO-recovered 0
# 17-07-20 14:45:13-INFO-Matching 188 trips to 322 rides in order to minimize u_veh
# 17-07-20 14:45:13-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,337
# reduced by matching to:               58,987
# 17-07-20 14:45:14-INFO-Day: 8	, quarantined: 27	 active today: 188.
# 17-07-20 14:45:14-INFO-state
# I     13
# Q     24
# S    283
# dtype: int64
# 17-07-20 14:45:14-INFO-day 9
# 17-07-20 14:45:14-INFO-recovered 0
# 17-07-20 14:45:15-INFO-Matching 187 trips to 326 rides in order to minimize u_veh
# 17-07-20 14:45:15-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,860
# reduced by matching to:               59,745
# 17-07-20 14:45:16-INFO-Day: 9	, quarantined: 26	 active today: 187.
# 17-07-20 14:45:16-INFO-state
# I     15
# Q     25
# S    280
# dtype: int64
# 17-07-20 14:45:16-INFO-day 10
# 17-07-20 14:45:16-INFO-recovered 0
# 17-07-20 14:45:17-INFO-Matching 183 trips to 311 rides in order to minimize u_veh
# 17-07-20 14:45:17-INFO-Problem solution: Optimal.
# Total costs for single trips:         60,923
# reduced by matching to:               56,408
# 17-07-20 14:45:17-INFO-Day: 10	, quarantined: 25	 active today: 183.
# 17-07-20 14:45:18-INFO-state
# I     15
# Q     25
# S    280
# dtype: int64
# 17-07-20 14:45:18-INFO-day 11
# 17-07-20 14:45:18-INFO-recovered 0
# 17-07-20 14:45:19-INFO-Matching 184 trips to 320 rides in order to minimize u_veh
# 17-07-20 14:45:19-INFO-Problem solution: Optimal.
# Total costs for single trips:         62,451
# reduced by matching to:               58,020
# 17-07-20 14:45:19-INFO-Day: 11	, quarantined: 25	 active today: 184.
# 17-07-20 14:45:20-INFO-state
# I     16
# Q     25
# S    279
# dtype: int64
# 17-07-20 14:45:20-INFO-day 12
# 17-07-20 14:45:20-INFO-recovered 0
# 17-07-20 14:45:20-INFO-Matching 187 trips to 300 rides in order to minimize u_veh
# 17-07-20 14:45:20-INFO-Problem solution: Optimal.
# Total costs for single trips:         62,878
# reduced by matching to:               58,782
# 17-07-20 14:45:21-INFO-Day: 12	, quarantined: 25	 active today: 187.
# 17-07-20 14:45:21-INFO-state
# I     17
# Q     25
# S    278
# dtype: int64
# 17-07-20 14:45:21-INFO-day 13
# 17-07-20 14:45:21-INFO-recovered 0
# 17-07-20 14:45:22-INFO-Matching 186 trips to 325 rides in order to minimize u_veh
# 17-07-20 14:45:22-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,705
# reduced by matching to:               59,429
# 17-07-20 14:45:22-INFO-Day: 13	, quarantined: 30	 active today: 186.
# 17-07-20 14:45:23-INFO-state
# I     15
# Q     27
# S    278
# dtype: int64
# 17-07-20 14:45:23-INFO-day 14
# 17-07-20 14:45:23-INFO-recovered 0
# 17-07-20 14:45:23-INFO-Matching 183 trips to 321 rides in order to minimize u_veh
# 17-07-20 14:45:23-INFO-Problem solution: Optimal.
# Total costs for single trips:         61,693
# reduced by matching to:               56,598
# 17-07-20 14:45:24-INFO-Day: 14	, quarantined: 29	 active today: 183.
# 17-07-20 14:45:24-INFO-state
# I     14
# Q     28
# S    278
# dtype: int64
# 17-07-20 14:45:24-INFO-day 15
# 17-07-20 14:45:24-INFO-recovered 0
# 17-07-20 14:45:25-INFO-Matching 183 trips to 311 rides in order to minimize u_veh
# 17-07-20 14:45:25-INFO-Problem solution: Optimal.
# Total costs for single trips:         61,936
# reduced by matching to:               57,682
# 17-07-20 14:45:25-INFO-Day: 15	, quarantined: 32	 active today: 183.
# 17-07-20 14:45:26-INFO-state
# I     12
# Q     30
# S    278
# dtype: int64
# 17-07-20 14:45:26-INFO-day 16
# 17-07-20 14:45:26-INFO-recovered 0
# 17-07-20 14:45:27-INFO-Matching 181 trips to 288 rides in order to minimize u_veh
# 17-07-20 14:45:27-INFO-Problem solution: Optimal.
# Total costs for single trips:         60,565
# reduced by matching to:               56,733
# 17-07-20 14:45:27-INFO-Day: 16	, quarantined: 34	 active today: 181.
# 17-07-20 14:45:28-INFO-state
# I      9
# Q     33
# S    278
# dtype: int64
# 17-07-20 14:45:28-INFO-day 17
# 17-07-20 14:45:28-INFO-recovered 0
# 17-07-20 14:45:28-INFO-Matching 177 trips to 280 rides in order to minimize u_veh
# 17-07-20 14:45:29-INFO-Problem solution: Optimal.
# Total costs for single trips:         58,049
# reduced by matching to:               54,577
# 17-07-20 14:45:29-INFO-Day: 17	, quarantined: 33	 active today: 177.
# 17-07-20 14:45:30-INFO-state
# I      9
# Q     33
# S    278
# dtype: int64
# 17-07-20 14:45:30-INFO-day 18
# 17-07-20 14:45:30-INFO-recovered 0
# 17-07-20 14:45:30-INFO-Matching 176 trips to 290 rides in order to minimize u_veh
# 17-07-20 14:45:30-INFO-Problem solution: Optimal.
# Total costs for single trips:         59,139
# reduced by matching to:               55,073
# 17-07-20 14:45:31-INFO-Day: 18	, quarantined: 34	 active today: 176.
# 17-07-20 14:45:31-INFO-state
# I      9
# Q     33
# S    278
# dtype: int64
# 17-07-20 14:45:31-INFO-day 19
# 17-07-20 14:45:31-INFO-recovered 0
# 17-07-20 14:45:32-INFO-Matching 180 trips to 297 rides in order to minimize u_veh
# 17-07-20 14:45:32-INFO-Problem solution: Optimal.
# Total costs for single trips:         58,764
# reduced by matching to:               55,261
# 17-07-20 14:45:33-INFO-Day: 19	, quarantined: 34	 active today: 180.
# 17-07-20 14:45:33-INFO-state
# I      8
# Q     34
# S    278
# dtype: int64
# 17-07-20 14:45:33-INFO-day 20
# 17-07-20 14:45:33-INFO-recovered 21
# 17-07-20 14:45:34-INFO-Matching 187 trips to 299 rides in order to minimize u_veh
# 17-07-20 14:45:34-INFO-Problem solution: Optimal.
# Total costs for single trips:         62,712
# reduced by matching to:               59,019
# 17-07-20 14:45:35-INFO-Day: 20	, quarantined: 16	 active today: 187.
# 17-07-20 14:45:35-INFO-state
# I      6
# Q     15
# R     21
# S    278
# dtype: int64
# 17-07-20 14:45:35-INFO-day 21
# 17-07-20 14:45:35-INFO-recovered 0
# 17-07-20 14:45:36-INFO-Matching 185 trips to 315 rides in order to minimize u_veh
# 17-07-20 14:45:36-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,223
# reduced by matching to:               59,675
# 17-07-20 14:45:36-INFO-Day: 21	, quarantined: 16	 active today: 185.
# 17-07-20 14:45:37-INFO-state
# I      6
# Q     15
# R     21
# S    278
# dtype: int64
# 17-07-20 14:45:37-INFO-day 22
# 17-07-20 14:45:37-INFO-recovered 3
# 17-07-20 14:45:38-INFO-Matching 190 trips to 318 rides in order to minimize u_veh
# 17-07-20 14:45:38-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,753
# reduced by matching to:               59,802
# 17-07-20 14:45:38-INFO-Day: 22	, quarantined: 14	 active today: 190.
# 17-07-20 14:45:38-INFO-state
# I      4
# Q     14
# R     24
# S    278
# dtype: int64
# 17-07-20 14:45:38-INFO-day 23
# 17-07-20 14:45:38-INFO-recovered 1
# 17-07-20 14:45:39-INFO-Matching 189 trips to 319 rides in order to minimize u_veh
# 17-07-20 14:45:39-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,208
# reduced by matching to:               58,793
# 17-07-20 14:45:39-INFO-Day: 23	, quarantined: 14	 active today: 189.
# 17-07-20 14:45:40-INFO-state
# I      4
# Q     13
# R     25
# S    278
# dtype: int64
# 17-07-20 14:45:40-INFO-day 24
# 17-07-20 14:45:40-INFO-recovered 0
# 17-07-20 14:45:41-INFO-Matching 192 trips to 317 rides in order to minimize u_veh
# 17-07-20 14:45:41-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,199
# reduced by matching to:               60,016
# 17-07-20 14:45:41-INFO-Day: 24	, quarantined: 13	 active today: 192.
# 17-07-20 14:45:42-INFO-state
# I      4
# Q     13
# R     25
# S    278
# dtype: int64
# 17-07-20 14:45:42-INFO-day 25
# 17-07-20 14:45:42-INFO-recovered 0
# 17-07-20 14:45:42-INFO-Matching 190 trips to 324 rides in order to minimize u_veh
# 17-07-20 14:45:42-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,228
# reduced by matching to:               60,548
# 17-07-20 14:45:43-INFO-Day: 25	, quarantined: 14	 active today: 190.
# 17-07-20 14:45:43-INFO-state
# I      3
# Q     14
# R     25
# S    278
# dtype: int64
# 17-07-20 14:45:43-INFO-day 26
# 17-07-20 14:45:43-INFO-recovered 0
# 17-07-20 14:45:44-INFO-Matching 187 trips to 308 rides in order to minimize u_veh
# 17-07-20 14:45:44-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,119
# reduced by matching to:               59,498
# 17-07-20 14:45:44-INFO-Day: 26	, quarantined: 14	 active today: 187.
# 17-07-20 14:45:45-INFO-state
# I      3
# Q     14
# R     25
# S    278
# dtype: int64
# 17-07-20 14:45:45-INFO-day 27
# 17-07-20 14:45:45-INFO-recovered 2
# 17-07-20 14:45:45-INFO-Matching 191 trips to 329 rides in order to minimize u_veh
# 17-07-20 14:45:45-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,656
# reduced by matching to:               59,550
# 17-07-20 14:45:46-INFO-Day: 27	, quarantined: 13	 active today: 191.
# 17-07-20 14:45:46-INFO-state
# I      3
# Q     12
# R     27
# S    278
# dtype: int64
# 17-07-20 14:45:46-INFO-day 28
# 17-07-20 14:45:46-INFO-recovered 1
# 17-07-20 14:45:47-INFO-Matching 190 trips to 314 rides in order to minimize u_veh
# 17-07-20 14:45:47-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,765
# reduced by matching to:               59,817
# 17-07-20 14:45:47-INFO-Day: 28	, quarantined: 12	 active today: 190.
# 17-07-20 14:45:48-INFO-state
# I      3
# Q     11
# R     28
# S    278
# dtype: int64
# 17-07-20 14:45:48-INFO-day 29
# 17-07-20 14:45:48-INFO-recovered 2
# 17-07-20 14:45:48-INFO-Matching 191 trips to 327 rides in order to minimize u_veh
# 17-07-20 14:45:48-INFO-Problem solution: Optimal.
# Total costs for single trips:         65,145
# reduced by matching to:               60,719
# 17-07-20 14:45:49-INFO-Day: 29	, quarantined: 9	 active today: 191.
# 17-07-20 14:45:49-INFO-state
# I      3
# Q      9
# R     30
# S    278
# dtype: int64
# 17-07-20 14:45:49-INFO-day 30
# 17-07-20 14:45:49-INFO-recovered 3
# 17-07-20 14:45:50-INFO-Matching 196 trips to 334 rides in order to minimize u_veh
# 17-07-20 14:45:50-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,642
# reduced by matching to:               60,002
# 17-07-20 14:45:50-INFO-Day: 30	, quarantined: 7	 active today: 196.
# 17-07-20 14:45:51-INFO-state
# I      2
# Q      7
# R     33
# S    278
# dtype: int64
# 17-07-20 14:45:51-INFO-day 31
# 17-07-20 14:45:51-INFO-recovered 0
# 17-07-20 14:45:51-INFO-Matching 194 trips to 310 rides in order to minimize u_veh
# 17-07-20 14:45:51-INFO-Problem solution: Optimal.
# Total costs for single trips:         62,277
# reduced by matching to:               58,574
# 17-07-20 14:45:52-INFO-Day: 31	, quarantined: 7	 active today: 194.
# 17-07-20 14:45:52-INFO-state
# I      2
# Q      7
# R     33
# S    278
# dtype: int64
# 17-07-20 14:45:52-INFO-day 32
# 17-07-20 14:45:52-INFO-recovered 0
# 17-07-20 14:45:53-INFO-Matching 194 trips to 351 rides in order to minimize u_veh
# 17-07-20 14:45:53-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,639
# reduced by matching to:               59,950
# 17-07-20 14:45:53-INFO-Day: 32	, quarantined: 7	 active today: 194.
# 17-07-20 14:45:54-INFO-state
# I      2
# Q      7
# R     33
# S    278
# dtype: int64
# 17-07-20 14:45:54-INFO-day 33
# 17-07-20 14:45:54-INFO-recovered 1
# 17-07-20 14:45:54-INFO-Matching 195 trips to 318 rides in order to minimize u_veh
# 17-07-20 14:45:54-INFO-Problem solution: Optimal.
# Total costs for single trips:         63,150
# reduced by matching to:               59,481
# 17-07-20 14:45:55-INFO-Day: 33	, quarantined: 6	 active today: 195.
# 17-07-20 14:45:55-INFO-state
# I      2
# Q      6
# R     34
# S    278
# dtype: int64
# 17-07-20 14:45:55-INFO-day 34
# 17-07-20 14:45:55-INFO-recovered 2
# 17-07-20 14:45:56-INFO-Matching 197 trips to 326 rides in order to minimize u_veh
# 17-07-20 14:45:56-INFO-Problem solution: Optimal.
# Total costs for single trips:         64,687
# reduced by matching to:               60,639
# 17-07-20 14:45:56-INFO-Day: 34	, quarantined: 5	 active today: 197.
# 17-07-20 14:45:57-INFO-state
# I      1
# Q      5
# R     36
# S    278
# dtype: int64
# 17-07-20 14:45:57-INFO-day 35
# 17-07-20 14:45:57-INFO-recovered 0
# 17-07-20 14:45:58-INFO-Matching 196 trips to 321 rides in order to minimize u_veh
# 17-07-20 14:45:58-INFO-Problem solution: Optimal.
# Total costs for single trips:         65,267
# reduced by matching to:               61,605
# 17-07-20 14:45:58-INFO-Day: 35	, quarantined: 6	 active today: 196.
# 17-07-20 14:45:58-INFO-state
# Q      6
# R     36
# S    278
# dtype: int64

# %%
ExMAS.corona.plot_spread(inData)

# %%
from ExMAS.utils import inData as inData

params = ExMAS.utils.get_config('ExMAS/data/configs/corona.json')
params.nP = 500
params = ExMAS.utils.make_paths(params)

params.t0 = pd.Timestamp.now()


inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the CITY graph

inData = ExMAS.utils.generate_demand(inData, params)

inData.passengers['platforms'] = inData.passengers.apply(lambda x: [0], axis=1)
inData.requests['platform'] = inData.requests.apply(lambda row: inData.passengers.loc[row.name].platforms[0],
                                                    axis=1)
inData.sblts.requests['platform'] = inData.requests['platform']
params.without_matching = True

inData = ExMAS.main(inData, params)
# Out:
# 17-07-20 12:34:20-INFO-Initializing pairwise trip shareability between 200 and 200 trips.
# 17-07-20 12:34:20-INFO-creating combinations
# 17-07-20 12:34:20-INFO-39800	 nR*(nR-1)
# 17-07-20 12:34:21-INFO-Reduction of feasible pairs by 99.84%
# 17-07-20 12:34:21-INFO-Degree 2 	Completed
# 17-07-20 12:34:21-INFO-trips to extend at degree 2 : 172
# 17-07-20 12:34:21-INFO-At degree 2 feasible extensions found out of 8 searched
# 17-07-20 12:34:21-INFO-Degree 3 	Completed
# 17-07-20 12:34:21-INFO-trips to extend at degree 3 : 8
# 17-07-20 12:34:21-INFO-At degree 3 feasible extensions found out of 0 searched
# 17-07-20 12:34:21-INFO-Degree 4 	Completed
# 17-07-20 12:34:21-INFO-No more trips to exted at degree 4

# %%
inData = ExMAS.corona.evolve(inData, params, _print=False, _plot = True)  # <---- MAIN
# Out:
# day 1
# 17-07-20 11:59:24-INFO-Matching 94 trips to 134 rides in order to minimize u_veh
# 17-07-20 11:59:24-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,169
# reduced by matching to:               31,180
# Re matching, 0 travellers quarantined, 106 inactive today. 385 out of 385 rides remain feasible
# day 2
# 17-07-20 11:59:24-INFO-Matching 104 trips to 154 rides in order to minimize u_veh
# 17-07-20 11:59:24-INFO-Problem solution: Optimal.
# Total costs for single trips:         37,180
# reduced by matching to:               34,751
# Re matching, 0 travellers quarantined, 96 inactive today. 385 out of 385 rides remain feasible
# day 3
# 17-07-20 11:59:25-INFO-Matching 97 trips to 140 rides in order to minimize u_veh
# 17-07-20 11:59:25-INFO-Problem solution: Optimal.
# Total costs for single trips:         35,173
# reduced by matching to:               32,703
# Re matching, 0 travellers quarantined, 103 inactive today. 385 out of 385 rides remain feasible
# day 4
# 17-07-20 11:59:26-INFO-Matching 92 trips to 129 rides in order to minimize u_veh
# 17-07-20 11:59:26-INFO-Problem solution: Optimal.
# Total costs for single trips:         31,528
# reduced by matching to:               29,968
# Re matching, 0 travellers quarantined, 108 inactive today. 385 out of 385 rides remain feasible
# day 5
# 17-07-20 11:59:27-INFO-Matching 100 trips to 140 rides in order to minimize u_veh
# 17-07-20 11:59:27-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,462
# reduced by matching to:               31,343
# Re matching, 6 travellers quarantined, 100 inactive today. 385 out of 385 rides remain feasible
# day 6
# 17-07-20 11:59:27-INFO-Matching 90 trips to 127 rides in order to minimize u_veh
# 17-07-20 11:59:27-INFO-Problem solution: Optimal.
# Total costs for single trips:         31,440
# reduced by matching to:               28,975
# Re matching, 4 travellers quarantined, 110 inactive today. 385 out of 385 rides remain feasible
# day 7
# 17-07-20 11:59:28-INFO-Matching 109 trips to 160 rides in order to minimize u_veh
# 17-07-20 11:59:28-INFO-Problem solution: Optimal.
# Total costs for single trips:         38,346
# reduced by matching to:               35,703
# Re matching, 6 travellers quarantined, 91 inactive today. 385 out of 385 rides remain feasible
# day 8
# 17-07-20 11:59:29-INFO-Matching 91 trips to 127 rides in order to minimize u_veh
# 17-07-20 11:59:29-INFO-Problem solution: Optimal.
# Total costs for single trips:         31,649
# reduced by matching to:               28,656
# Re matching, 7 travellers quarantined, 109 inactive today. 385 out of 385 rides remain feasible
# day 9
# 17-07-20 11:59:30-INFO-Matching 94 trips to 136 rides in order to minimize u_veh
# 17-07-20 11:59:30-INFO-Problem solution: Optimal.
# Total costs for single trips:         34,057
# reduced by matching to:               31,419
# Re matching, 7 travellers quarantined, 106 inactive today. 385 out of 385 rides remain feasible
# day 10
# 17-07-20 11:59:31-INFO-Matching 96 trips to 139 rides in order to minimize u_veh
# 17-07-20 11:59:31-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,996
# reduced by matching to:               31,762
# Re matching, 5 travellers quarantined, 104 inactive today. 385 out of 385 rides remain feasible
# day 11
# 17-07-20 11:59:31-INFO-Matching 102 trips to 153 rides in order to minimize u_veh
# 17-07-20 11:59:31-INFO-Problem solution: Optimal.
# Total costs for single trips:         37,046
# reduced by matching to:               33,859
# Re matching, 7 travellers quarantined, 98 inactive today. 385 out of 385 rides remain feasible
# day 12
# 17-07-20 11:59:32-INFO-Matching 92 trips to 136 rides in order to minimize u_veh
# 17-07-20 11:59:32-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,066
# reduced by matching to:               30,884
# Re matching, 6 travellers quarantined, 108 inactive today. 385 out of 385 rides remain feasible
# day 13
# 17-07-20 11:59:33-INFO-Matching 94 trips to 136 rides in order to minimize u_veh
# 17-07-20 11:59:33-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,543
# reduced by matching to:               31,551
# Re matching, 7 travellers quarantined, 106 inactive today. 385 out of 385 rides remain feasible
# day 14
# 17-07-20 11:59:34-INFO-Matching 95 trips to 129 rides in order to minimize u_veh
# 17-07-20 11:59:34-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,540
# reduced by matching to:               30,724
# Re matching, 8 travellers quarantined, 105 inactive today. 385 out of 385 rides remain feasible
# day 15
# 17-07-20 11:59:35-INFO-Matching 99 trips to 147 rides in order to minimize u_veh
# 17-07-20 11:59:35-INFO-Problem solution: Optimal.
# Total costs for single trips:         36,382
# reduced by matching to:               33,574
# Re matching, 10 travellers quarantined, 101 inactive today. 385 out of 385 rides remain feasible
# day 16
# 17-07-20 11:59:36-INFO-Matching 95 trips to 143 rides in order to minimize u_veh
# 17-07-20 11:59:36-INFO-Problem solution: Optimal.
# Total costs for single trips:         35,050
# reduced by matching to:               32,599
# Re matching, 10 travellers quarantined, 105 inactive today. 385 out of 385 rides remain feasible
# day 17
# 17-07-20 11:59:36-INFO-Matching 91 trips to 134 rides in order to minimize u_veh
# 17-07-20 11:59:36-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,240
# reduced by matching to:               29,442
# Re matching, 11 travellers quarantined, 109 inactive today. 385 out of 385 rides remain feasible
# day 18
# 17-07-20 11:59:37-INFO-Matching 88 trips to 122 rides in order to minimize u_veh
# 17-07-20 11:59:37-INFO-Problem solution: Optimal.
# Total costs for single trips:         29,547
# reduced by matching to:               27,686
# Re matching, 11 travellers quarantined, 112 inactive today. 385 out of 385 rides remain feasible
# day 19
# 17-07-20 11:59:38-INFO-Matching 93 trips to 137 rides in order to minimize u_veh
# 17-07-20 11:59:38-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,910
# reduced by matching to:               31,639
# Re matching, 12 travellers quarantined, 107 inactive today. 385 out of 385 rides remain feasible

# %%
inData.passengers.groupby('active_today').size()
# Out:
# active_today
# False    2015
# True     1985
# dtype: int64

# %%
inData.passengers.groupby('active').size()
# Out:
# active
# True    4000
# dtype: int64

# %%
inData = ExMAS.main(inData, params)
# Out:
# 16-07-20 15:49:28-INFO-Initializing pairwise trip shareability between 200 and 200 trips.
# 16-07-20 15:49:28-INFO-creating combinations
# 16-07-20 15:49:29-INFO-39800	 nR*(nR-1)
# 16-07-20 15:49:30-INFO-Reduction of feasible pairs by 99.34%
# 16-07-20 15:49:30-INFO-Degree 2 	Completed
# 16-07-20 15:49:30-INFO-trips to extend at degree 2 : 694
# 16-07-20 15:49:31-INFO-At degree 2 feasible extensions found out of 88 searched
# 16-07-20 15:49:31-INFO-Degree 3 	Completed
# 16-07-20 15:49:31-INFO-trips to extend at degree 3 : 88
# 16-07-20 15:49:31-INFO-At degree 3 feasible extensions found out of 7 searched
# 16-07-20 15:49:31-INFO-Degree 4 	Completed
# 16-07-20 15:49:31-INFO-trips to extend at degree 4 : 7
# 16-07-20 15:49:31-INFO-At degree 4 feasible extensions found out of 0 searched
# 16-07-20 15:49:31-INFO-Degree 5 	Completed
# 16-07-20 15:49:31-INFO-No more trips to exted at degree 5
# 16-07-20 15:49:32-INFO-Matching 200 trips to 989 rides in order to minimize u_veh
# 16-07-20 15:49:33-INFO-Problem solution: Optimal.
# Total costs for single trips:         70,646
# reduced by matching to:               56,927
# 16-07-20 15:49:33-INFO-Calculations  completed
# 16-07-20 15:49:33-INFO-DotMap(VehHourTrav=56267, VehHourTrav_ns=70646, PassHourTrav=79369, PassHourTrav_ns=70646, PassUtility=1047.0545499999998, PassUtility_ns=1096.144, mean_lambda=0.2619879690633057, revenue_s=74178.29999999999, revenue_ns=105969.0, Fare_Discount=-0.3000000000000001, nR=200, SINGLE=75, PAIRS=44, TRIPLES=11, QUADRIPLES=1, QUINTETS=0, PLUS5=0, shared_ratio=0.625, fleet_size_nonshared=32.0, fleet_size_shared=23.0, lambda_shared=0.2619879690633057)

# %% [markdown]
# ### initially infected population
# (one realization)

# %% [markdown]
# ### Infecting - single day
#
# infected traveller '43' travelled with two other travellers (`191` and `215`)
# they travel together and `43` infects them

# %%
infector = inData.population.query('state == "I"').iloc[10]
infector.to_frame().T
# Out:
#     state infection_day infected_by
# 190     I        -3.000        None

# %%
for i, ride in schedule.iterrows():
    if infector.name in ride.indexes:
        r = ride.name
        break
travellers = schedule.loc[r]
travellers.to_frame().T
# Out:
#      Unnamed: 0     indexes u_pax u_veh kind                       u_paxes  \
# 1686      33285  [190, 258] 7.750   529   21  [5.2164, 2.5336499999999997]
#
#                        times indexes_orig indexes_dest degree index lambda_r  \
# 1686  [374.0, 102, 194, 223]   [190, 258]   [258, 190]  2.000   NaN    0.020
#
#      PassHourTrav_ns selected
# 1686             540        1

# %%
inData = infect(inData, day = 0, params = params)

# %%
inData.population.loc[travellers.indexes]
# Out:
#     state  infection_day infected_by
# 190     I         -3.000        None
# 258     I          0.000     190.000

# %% [markdown]
# ### Evolution

# %%
params.corona.one = False
inData.sblts.rides = rides
inData.requests = requests
inData.sblts.requests = requests
inData.sblts.schedule = schedule
params.corona.infected_prior = 3
inData = evolve(inData, params, _print = False, _plot = True)
# Out:
# day 1
# day 2
# day 3
# day 4
# day 5
# day 6
# day 7
# day 8
# day 9
# day 10
# day 11
# day 12
# day 13
# day 14
# day 15
# day 16
# day 17
# day 18
# day 19
# day 20
# day 21
# day 22
# day 23
# day 24
# day 25
# day 26
# day 27
