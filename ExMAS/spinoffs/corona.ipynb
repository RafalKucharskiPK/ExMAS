# %%
import os
cwd = os.getcwd()

# %%
os.chdir(os.path.join(cwd,'../..'))
import ExMAS.main
import ExMAS.utils
import ExMAS.corona

# %%
from ExMAS.utils import inData as inData

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
pd.options.display.float_format = '{:.3f}'.format
import numpy as np
from math import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import json
from scipy.stats import *


import pprint

# %%
plt.rcParams['figure.figsize'] = [16, 4]
plt.rcParams["font.family"] = "Helvetica"
plt.style.use('ggplot')
colors = sns.color_palette("muted")

# %% [markdown]
# ---
# params

# %%
params = ExMAS.utils.get_config('ExMAS/data/configs/corona.json')  # configuration, including shareability parameters (to reproduce utility)
params.nP = 4000
params.simTime = 4
params.corona.initial_share = 0.05  # initial probability of being infected
params.corona.time_threshold = 60  # minimal time of travelling together to infect
params.corona.infected_prior = 3  # minimal time of travelling together to infect
params.corona.time_to_quarantine = 6  # minimal time of travelling together to infect
params.corona.participation = 0.5
params.corona.p = 0.8
params.multi_platform_matching = True
params.corona.one = False
params.corona.big = True  # small set of 300 trips to test and big of 3000 for proper experiments

# %%
params.t0 = '15:00'
ExMAS.utils.save_config(params, path = 'ExMAS/data/configs/corona.json')

# %%
from ExMAS.utils import inData as inData

params = ExMAS.utils.get_config('ExMAS/data/configs/corona.json')
params.nP = 200
params = ExMAS.utils.make_paths(params)

params.t0 = pd.Timestamp.now()



inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the CITY graph

inData = ExMAS.utils.generate_demand(inData, params)

inData.passengers['platforms'] = inData.passengers.apply(lambda x: [0], axis=1)
inData.requests['platform'] = inData.requests.apply(lambda row: inData.passengers.loc[row.name].platforms[0],
                                                    axis=1)
inData.sblts.requests['platform'] = inData.requests['platform']
params.without_matching = True

inData = ExMAS.main(inData, params)
# Out:
# 16-07-20 16:58:57-INFO-Initializing pairwise trip shareability between 200 and 200 trips.
# 16-07-20 16:58:57-INFO-creating combinations
# 16-07-20 16:58:57-INFO-39800	 nR*(nR-1)
# 16-07-20 16:58:57-INFO-Reduction of feasible pairs by 99.87%
# 16-07-20 16:58:57-INFO-Degree 2 	Completed
# 16-07-20 16:58:57-INFO-trips to extend at degree 2 : 122
# 16-07-20 16:58:58-INFO-At degree 2 feasible extensions found out of 0 searched
# 16-07-20 16:58:58-INFO-Degree 3 	Completed
# 16-07-20 16:58:58-INFO-No more trips to exted at degree 3

# %%
inData = ExMAS.corona.evolve(inData, params, _print=False, _plot = True)  # <---- MAIN
# Out:
# day 1
# 16-07-20 16:59:59-INFO-Matching 107 trips to 146 rides in order to minimize u_veh
# 16-07-20 16:59:59-INFO-Problem solution: Optimal.
# Total costs for single trips:         34,597
# reduced by matching to:               32,764
# Re matching, 0 travellers quarantined, 92 inactive today. 322 out of 322 rides remain feasible
# day 2
# 16-07-20 17:00:00-INFO-Matching 96 trips to 133 rides in order to minimize u_veh
# 16-07-20 17:00:00-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,239
# reduced by matching to:               30,511
# Re matching, 0 travellers quarantined, 103 inactive today. 322 out of 322 rides remain feasible
# day 3
# 16-07-20 17:00:00-INFO-Matching 99 trips to 141 rides in order to minimize u_veh
# 16-07-20 17:00:00-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,630
# reduced by matching to:               30,361
# Re matching, 0 travellers quarantined, 100 inactive today. 322 out of 322 rides remain feasible
# day 4
# 16-07-20 17:00:01-INFO-Matching 98 trips to 126 rides in order to minimize u_veh
# 16-07-20 17:00:01-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,976
# reduced by matching to:               29,380
# Re matching, 0 travellers quarantined, 101 inactive today. 322 out of 322 rides remain feasible
# day 5
# 16-07-20 17:00:02-INFO-Matching 101 trips to 137 rides in order to minimize u_veh
# 16-07-20 17:00:02-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,243
# reduced by matching to:               30,310
# Re matching, 9 travellers quarantined, 98 inactive today. 322 out of 322 rides remain feasible
# day 6
# 16-07-20 17:00:03-INFO-Matching 85 trips to 113 rides in order to minimize u_veh
# 16-07-20 17:00:03-INFO-Problem solution: Optimal.
# Total costs for single trips:         27,175
# reduced by matching to:               25,824
# Re matching, 7 travellers quarantined, 114 inactive today. 322 out of 322 rides remain feasible
# day 7
# 16-07-20 17:00:03-INFO-Matching 102 trips to 139 rides in order to minimize u_veh
# 16-07-20 17:00:03-INFO-Problem solution: Optimal.
# Total costs for single trips:         33,140
# reduced by matching to:               31,247
# Re matching, 8 travellers quarantined, 97 inactive today. 322 out of 322 rides remain feasible
# day 8
# 16-07-20 17:00:04-INFO-Matching 93 trips to 123 rides in order to minimize u_veh
# 16-07-20 17:00:04-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,664
# reduced by matching to:               29,002
# Re matching, 9 travellers quarantined, 106 inactive today. 322 out of 322 rides remain feasible
# day 9
# 16-07-20 17:00:05-INFO-Matching 90 trips to 118 rides in order to minimize u_veh
# 16-07-20 17:00:05-INFO-Problem solution: Optimal.
# Total costs for single trips:         29,977
# reduced by matching to:               28,626
# Re matching, 9 travellers quarantined, 110 inactive today. 322 out of 322 rides remain feasible
# day 10
# 16-07-20 17:00:05-INFO-Matching 99 trips to 131 rides in order to minimize u_veh
# 16-07-20 17:00:05-INFO-Problem solution: Optimal.
# Total costs for single trips:         32,590
# reduced by matching to:               31,099
# Re matching, 9 travellers quarantined, 100 inactive today. 322 out of 322 rides remain feasible
# day 11
# 16-07-20 17:00:06-INFO-Matching 89 trips to 122 rides in order to minimize u_veh
# 16-07-20 17:00:06-INFO-Problem solution: Optimal.
# Total costs for single trips:         29,650
# reduced by matching to:               27,892
# Re matching, 11 travellers quarantined, 110 inactive today. 322 out of 322 rides remain feasible
# day 12
# 16-07-20 17:00:07-INFO-Matching 95 trips to 128 rides in order to minimize u_veh
# 16-07-20 17:00:07-INFO-Problem solution: Optimal.
# Total costs for single trips:         31,242
# reduced by matching to:               29,647
# Re matching, 9 travellers quarantined, 104 inactive today. 322 out of 322 rides remain feasible
# day 13
# 16-07-20 17:00:07-INFO-Matching 81 trips to 109 rides in order to minimize u_veh
# 16-07-20 17:00:07-INFO-Problem solution: Optimal.
# Total costs for single trips:         28,329
# reduced by matching to:               26,455
# Re matching, 10 travellers quarantined, 118 inactive today. 322 out of 322 rides remain feasible
# day 14
# 16-07-20 17:00:08-INFO-Matching 86 trips to 108 rides in order to minimize u_veh
# 16-07-20 17:00:08-INFO-Problem solution: Optimal.
# Total costs for single trips:         27,597
# reduced by matching to:               26,507
# Re matching, 10 travellers quarantined, 114 inactive today. 322 out of 322 rides remain feasible
# day 15
# 16-07-20 17:00:09-INFO-Matching 94 trips to 116 rides in order to minimize u_veh
# 16-07-20 17:00:09-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,188
# reduced by matching to:               28,853
# Re matching, 9 travellers quarantined, 105 inactive today. 322 out of 322 rides remain feasible
# day 16
# 16-07-20 17:00:10-INFO-Matching 80 trips to 110 rides in order to minimize u_veh
# 16-07-20 17:00:10-INFO-Problem solution: Optimal.
# Total costs for single trips:         25,783
# reduced by matching to:               24,158
# Re matching, 9 travellers quarantined, 120 inactive today. 322 out of 322 rides remain feasible
# day 17
# 16-07-20 17:00:10-INFO-Matching 93 trips to 126 rides in order to minimize u_veh
# 16-07-20 17:00:10-INFO-Problem solution: Optimal.
# Total costs for single trips:         29,967
# reduced by matching to:               28,464
# Re matching, 11 travellers quarantined, 106 inactive today. 322 out of 322 rides remain feasible
# day 18
# 16-07-20 17:00:11-INFO-Matching 95 trips to 122 rides in order to minimize u_veh
# 16-07-20 17:00:11-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,720
# reduced by matching to:               29,353
# Re matching, 9 travellers quarantined, 104 inactive today. 322 out of 322 rides remain feasible
# day 19
# 16-07-20 17:00:12-INFO-Matching 90 trips to 116 rides in order to minimize u_veh
# 16-07-20 17:00:12-INFO-Problem solution: Optimal.
# Total costs for single trips:         29,317
# reduced by matching to:               28,118
# Re matching, 10 travellers quarantined, 109 inactive today. 322 out of 322 rides remain feasible
# day 20
# 16-07-20 17:00:13-INFO-Matching 87 trips to 113 rides in order to minimize u_veh
# 16-07-20 17:00:13-INFO-Problem solution: Optimal.
# Total costs for single trips:         27,653
# reduced by matching to:               26,440
# Re matching, 11 travellers quarantined, 112 inactive today. 322 out of 322 rides remain feasible
# day 21
# 16-07-20 17:00:13-INFO-Matching 96 trips to 122 rides in order to minimize u_veh
# 16-07-20 17:00:13-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,190
# reduced by matching to:               28,851
# Re matching, 10 travellers quarantined, 103 inactive today. 322 out of 322 rides remain feasible
# day 22
# 16-07-20 17:00:14-INFO-Matching 92 trips to 126 rides in order to minimize u_veh
# 16-07-20 17:00:14-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,804
# reduced by matching to:               29,211
# Re matching, 10 travellers quarantined, 107 inactive today. 322 out of 322 rides remain feasible
# day 23
# 16-07-20 17:00:15-INFO-Matching 93 trips to 125 rides in order to minimize u_veh
# 16-07-20 17:00:15-INFO-Problem solution: Optimal.
# Total costs for single trips:         30,838
# reduced by matching to:               29,211
# Re matching, 12 travellers quarantined, 106 inactive today. 322 out of 322 rides remain feasible
# day 24
# 16-07-20 17:00:16-INFO-Matching 95 trips to 127 rides in order to minimize u_veh
# 16-07-20 17:00:16-INFO-Problem solution: Optimal.
# Total costs for single trips:         31,379
# reduced by matching to:               29,576
# Re matching, 12 travellers quarantined, 104 inactive today. 322 out of 322 rides remain feasible
# day 25
# 16-07-20 17:00:17-INFO-Matching 87 trips to 114 rides in order to minimize u_veh
# 16-07-20 17:00:17-INFO-Problem solution: Optimal.
# Total costs for single trips:         27,881
# reduced by matching to:               26,656
# Re matching, 12 travellers quarantined, 112 inactive today. 322 out of 322 rides remain feasible
# day 26
# 16-07-20 17:00:17-INFO-Matching 87 trips to 110 rides in order to minimize u_veh
# 16-07-20 17:00:17-INFO-Problem solution: Optimal.
# Total costs for single trips:         28,103
# reduced by matching to:               26,676
# Re matching, 13 travellers quarantined, 113 inactive today. 322 out of 322 rides remain feasible

# %%
inData.passengers.groupby('active_today').size()
# Out:
# active_today
# False    2015
# True     1985
# dtype: int64

# %%
inData.passengers.groupby('active').size()
# Out:
# active
# True    4000
# dtype: int64

# %%
inData = ExMAS.main(inData, params)
# Out:
# 16-07-20 15:49:28-INFO-Initializing pairwise trip shareability between 200 and 200 trips.
# 16-07-20 15:49:28-INFO-creating combinations
# 16-07-20 15:49:29-INFO-39800	 nR*(nR-1)
# 16-07-20 15:49:30-INFO-Reduction of feasible pairs by 99.34%
# 16-07-20 15:49:30-INFO-Degree 2 	Completed
# 16-07-20 15:49:30-INFO-trips to extend at degree 2 : 694
# 16-07-20 15:49:31-INFO-At degree 2 feasible extensions found out of 88 searched
# 16-07-20 15:49:31-INFO-Degree 3 	Completed
# 16-07-20 15:49:31-INFO-trips to extend at degree 3 : 88
# 16-07-20 15:49:31-INFO-At degree 3 feasible extensions found out of 7 searched
# 16-07-20 15:49:31-INFO-Degree 4 	Completed
# 16-07-20 15:49:31-INFO-trips to extend at degree 4 : 7
# 16-07-20 15:49:31-INFO-At degree 4 feasible extensions found out of 0 searched
# 16-07-20 15:49:31-INFO-Degree 5 	Completed
# 16-07-20 15:49:31-INFO-No more trips to exted at degree 5
# 16-07-20 15:49:32-INFO-Matching 200 trips to 989 rides in order to minimize u_veh
# 16-07-20 15:49:33-INFO-Problem solution: Optimal.
# Total costs for single trips:         70,646
# reduced by matching to:               56,927
# 16-07-20 15:49:33-INFO-Calculations  completed
# 16-07-20 15:49:33-INFO-DotMap(VehHourTrav=56267, VehHourTrav_ns=70646, PassHourTrav=79369, PassHourTrav_ns=70646, PassUtility=1047.0545499999998, PassUtility_ns=1096.144, mean_lambda=0.2619879690633057, revenue_s=74178.29999999999, revenue_ns=105969.0, Fare_Discount=-0.3000000000000001, nR=200, SINGLE=75, PAIRS=44, TRIPLES=11, QUADRIPLES=1, QUINTETS=0, PLUS5=0, shared_ratio=0.625, fleet_size_nonshared=32.0, fleet_size_shared=23.0, lambda_shared=0.2619879690633057)

# %% [markdown]
# ### initially infected population
# (one realization)

# %% [markdown]
# ### Infecting - single day
#
# infected traveller '43' travelled with two other travellers (`191` and `215`)
# they travel together and `43` infects them

# %%
infector = inData.population.query('state == "I"').iloc[10]
infector.to_frame().T
# Out:
#     state infection_day infected_by
# 190     I        -3.000        None

# %%
for i, ride in schedule.iterrows():
    if infector.name in ride.indexes:
        r = ride.name
        break
travellers = schedule.loc[r]
travellers.to_frame().T
# Out:
#      Unnamed: 0     indexes u_pax u_veh kind                       u_paxes  \
# 1686      33285  [190, 258] 7.750   529   21  [5.2164, 2.5336499999999997]
#
#                        times indexes_orig indexes_dest degree index lambda_r  \
# 1686  [374.0, 102, 194, 223]   [190, 258]   [258, 190]  2.000   NaN    0.020
#
#      PassHourTrav_ns selected
# 1686             540        1

# %%
inData = infect(inData, day = 0, params = params)

# %%
inData.population.loc[travellers.indexes]
# Out:
#     state  infection_day infected_by
# 190     I         -3.000        None
# 258     I          0.000     190.000

# %% [markdown]
# ### Evolution

# %%
params.corona.one = False
inData.sblts.rides = rides
inData.requests = requests
inData.sblts.requests = requests
inData.sblts.schedule = schedule
params.corona.infected_prior = 3
inData = evolve(inData, params, _print = False, _plot = True)
# Out:
# day 1
# day 2
# day 3
# day 4
# day 5
# day 6
# day 7
# day 8
# day 9
# day 10
# day 11
# day 12
# day 13
# day 14
# day 15
# day 16
# day 17
# day 18
# day 19
# day 20
# day 21
# day 22
# day 23
# day 24
# day 25
# day 26
# day 27
