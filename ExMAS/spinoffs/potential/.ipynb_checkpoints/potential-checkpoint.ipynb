# %% [markdown]
# ## ExMAS
# > Exact Matching of Attractive Shared rides (ExMAS) for system-wide strategic evaluations
# >
# > Kucharski R., Cats O. ,_Transportation Research Part: B_, 2020
#
# ---
# #### Shareability potential

# %%
import os
import pandas as pd
# %load_ext autoreload
# %autoreload 2
cwd = os.getcwd()

# %%
os.chdir(os.path.join(cwd,'../..'))
import ExMAS.main
import ExMAS.utils

# %%
from ExMAS.utils import inData as inData

# %% [markdown]
# ### prepare

# %% [markdown]
# 1. __make the config__ (see more details in `ExMAS/notebooks/01 configuration.ipynb`)

# %%
params = ExMAS.utils.get_config('ExMAS/data/configs/default.json') # load the default

# %%
params.gammdist.shape = 2
params.gammdist.scale = 500
params.gamma_imp.shape = 1.15
params.gamma_imp.scale = 3200
params.nP = 100
params.nCenters = 3
params.city = 'Amsterdam, Netherlands'
params.t0 = '17:00'
params = ExMAS.utils.make_paths(params)
ExMAS.utils.save_config(params, path = 'ExMAS/data/configs/potential.json')

# %%
params.t0 = pd.to_datetime(params.t0)

# %% [markdown]
# 2. __load the network__ (see more details in `ExMAS/notebooks/02 NetworkGraphs.ipynb`)

# %%
inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the graph

# %% [markdown]
# 3. __generate trip requests__ (see more details in `ExMAS/notebooks/03 Demand Generation.ipynb`)

# %%
inData = ExMAS.utils.synthetic_demand_poly_II(inData, params)

# %%
poly = inData.requests.copy()

# %%
inData = ExMAS.utils.generate_demand(inData, params)
ex = inData.requests.copy()

# %% [markdown]
# 4. __save requests__

# %%
inData.requests.to_csv('ExMAS/spinoffs/poly_demand.csv')

# %%
inData.sblts.pairs
# Out:
#              origin_i  destination_i  ttrav_i  treq_i     delta_i  dist_i  \
# i  j  kind
# 2  6  20     46328761      291130803      690      49  386.802198    5521
#       21     46328761      291130803      690      49  386.802198    5521
#    10 21     46328761      291130803      690      49  386.802198    5521
#    19 20     46328761      291130803      690      49  386.802198    5521
#    24 20     46328761      291130803      690      49  386.802198    5521
# ...               ...            ...      ...     ...         ...     ...
# 84 99 20    418024105       46361992      601    2749  337.516484    4815
# 86 92 20     46401742       46444801      539    2846  302.274725    4314
#    96 20     46401742       46444801      539    2846  302.274725    4314
# 87 89 20     46297656       46394632      455    2869  255.395604    3644
# 89 87 20    299709594       46400085      485    3100  272.505495    3887
#
#              VoT_i    origin_j  destination_j  ttrav_j  ...  indexes_orig  \
# i  j  kind                                              ...
# 2  6  20    0.0035    46332038       46404705      503  ...        [2, 6]
#       21    0.0035    46332038       46404705      503  ...        [2, 6]
#    10 21    0.0035  1582427317       46367893      273  ...       [2, 10]
#    19 20    0.0035    46406087     5420352485      650  ...       [2, 19]
#    24 20    0.0035    46421864       46305753      475  ...       [2, 24]
# ...            ...         ...            ...      ...  ...           ...
# 84 99 20    0.0035    46336500     2673087264      506  ...      [84, 99]
# 86 92 20    0.0035  2020614369     3300515594      347  ...      [86, 92]
#    96 20    0.0035  4949301843     1306733851      626  ...      [86, 96]
# 87 89 20    0.0035   299709594       46400085      485  ...      [87, 89]
# 89 87 20    0.0035    46297656       46394632      455  ...      [89, 87]
#
#             indexes_dest       u_i      u_j  t_i  t_j    delta_ij    delta_ji  \
# i  j  kind
# 2  6  20          [2, 6]   9.24140  7.47600  719  676  319.802198   71.098901
#       21          [6, 2]  10.25150  6.68885  941  503  127.802198  244.098901
#    10 21         [10, 2]  10.08770  3.63510  922  273  163.802198  132.395604
#    19 20         [2, 19]  10.10135  9.16335  859  726  130.802198  201.681319
#
#                    tarr tdrop  dist  pax_id
# 100 2020-09-21 16:59:20   NaN  1741     100
# 43  2020-09-21 17:06:50   NaN  2187      43
# 90  2020-09-21 17:22:06   NaN  3080      90
# 28  2020-09-21 17:14:34   NaN  2601      28
# 20  2020-09-21 18:51:40   NaN  8372      20
# ..                  ...   ...   ...     ...
# 62  2020-09-21 17:58:47   NaN  1855      62
# 13  2020-09-21 18:31:43   NaN  3787      13
# 61  2020-09-21 18:34:25   NaN  3912      61
# 33  2020-09-21 18:30:13   NaN  3641      33
# 64  2020-09-21 19:29:18   NaN  7179      64
#
# [100 rows x 9 columns]

# %% [markdown]
# 5. __load requests__

# %%
inData.requests = pd.read_csv('ExMAS/spinoffs/poly_demand.csv', index_col = 0)
inData.requests.dist = inData.requests.apply(lambda request: inData.skim.loc[request.origin, request.destination], axis=1)
inData.requests.treq = pd.to_datetime(inData.requests.treq)
inData.requests['pax_id'] = inData.requests.index.copy()
inData.requests.tarr = pd.to_datetime(inData.requests.tarr)
inData.requests.ttrav = pd.to_timedelta(inData.requests.ttrav)

# %% [markdown]
# 5. __visualize demand__

# %%
ExMAS.utils.plot_demand_poly(inData, params)

# %% [markdown]
# ### run

# %%
inData = ExMAS.main(inData, params, plot = True)
# Out:
# 21-09-20 11:33:09-INFO-Initializing pairwise trip shareability between 100 and 100 trips.
# 21-09-20 11:33:09-INFO-creating combinations
# 21-09-20 11:33:09-INFO-9900	 nR*(nR-1)
# 21-09-20 11:33:09-INFO-3863	departure compatibility
# 21-09-20 11:33:10-INFO-1635	origins shareability
# 21-09-20 11:33:10-INFO-301	utility for i
# 21-09-20 11:33:10-INFO-64	utility for j
# 21-09-20 11:33:10-CRITICAL-FIFO pairs assertion failed
# 21-09-20 11:33:10-WARNING-        origin_i  destination_i  ttrav_i  treq_i    delta_i  dist_i   VoT_i  \
# i  j
# 25 27  722976564       46370376      284     899  135.32967    2031  0.0035
#
#        origin_j  destination_j  ttrav_j  ...  indexes_orig  indexes_dest  \
# i  j                                     ...
# 25 27  46347485       46366881      402  ...      [25, 27]      [25, 27]
#
#           u_i     u_j  t_i  t_j  delta_ij   delta_ji      delta   u_pax
# i  j
# 25 27  3.6204  5.7337  270  506  92.32967  45.010989  45.010989  9.3541
#
# [1 rows x 35 columns]
# 21-09-20 11:33:10-WARNING-       origin_i  destination_i  ttrav_i  treq_i     delta_i  dist_i   VoT_i  \
# i  j
# 10 24  46235831       46364819      558     342  295.615385    4291  0.0035
#
#        origin_j  destination_j  ttrav_j  ...  indexes_orig  indexes_dest  \
# i  j                                     ...
# 10 24  46383339       46382454      338  ...      [10, 24]      [10, 24]
#
#             u_i       u_j  t_i  t_j   delta_ij    delta_ji      delta    u_pax
# i  j
# 10 24  7.943075  3.388525  741  274  98.115385  167.027473  98.115385  11.3316
#
# [1 rows x 35 columns]
# 21-09-20 11:33:10-WARNING-Empty DataFrame
# Columns: [origin_i, destination_i, ttrav_i, treq_i, delta_i, dist_i, VoT_i, origin_j, destination_j, ttrav_j, treq_j, delta_j, dist_j, VoT_j, i, j, t_oo, delay, delay_i, delay_j, t_od, t_dd, ttrav, kind, indexes, indexes_orig, indexes_dest, u_i, u_j, t_i, t_j, delta_ij, delta_ji, delta, u_pax]
# Index: []
#
# [0 rows x 35 columns]
# 21-09-20 11:33:10-WARNING-Empty DataFrame
# Columns: [origin_i, destination_i, ttrav_i, treq_i, delta_i, dist_i, VoT_i, origin_j, destination_j, ttrav_j, treq_j, delta_j, dist_j, VoT_j, i, j, t_oo, delay, delay_i, delay_j, t_od, t_dd, ttrav, kind, indexes, indexes_orig, indexes_dest, u_i, u_j, t_i, t_j, delta_ij, delta_ji, delta, u_pax]
# Index: []
#
# [0 rows x 35 columns]
# 21-09-20 11:33:10-WARNING-Empty DataFrame
# Columns: [origin_i, destination_i, ttrav_i, treq_i, delta_i, dist_i, VoT_i, origin_j, destination_j, ttrav_j, treq_j, delta_j, dist_j, VoT_j, i, j, t_oo, delay, delay_i, delay_j, t_od, t_dd, ttrav, kind, indexes, indexes_orig, indexes_dest, u_i, u_j, t_i, t_j, delta_ij, delta_ji, delta, u_pax]
# Index: []
#
# [0 rows x 35 columns]
# 21-09-20 11:33:10-WARNING-Empty DataFrame
# Columns: [origin_i, destination_i, ttrav_i, treq_i, delta_i, dist_i, VoT_i, origin_j, destination_j, ttrav_j, treq_j, delta_j, dist_j, VoT_j, i, j, t_oo, delay, delay_i, delay_j, t_od, t_dd, ttrav, kind, indexes, indexes_orig, indexes_dest, u_i, u_j, t_i, t_j, delta_ij, delta_ji, delta, u_pax]
# Index: []
#
# [0 rows x 35 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/Documents/GitHub/ExMAS/ExMAS/main.py in check_me_FIFO()
#     344         try:
# --> 345             assert (r.t_i - r.ttrav_i > -3).all()  # share time is not smaller than direct
#     346             assert (r.t_j - r.ttrav_j > -3).all()
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-a055836c080a> in <module>
# ----> 1 inData = ExMAS.main(inData, params, plot = True)
#
# ~/Documents/GitHub/ExMAS/ExMAS/main.py in main(_inData, params, plot)
#     113     degree = 1
#     114
# --> 115     _inData = pairs(_inData, params, plot=plot)
#     116     degree = 2
#     117     _inData.logger.info('Degree {} \tCompleted'.format(degree))
#
# ~/Documents/GitHub/ExMAS/ExMAS/main.py in pairs(_inData, params, process, check, plot)
#     493         r['delta'] = r[['delta_ji', 'delta_ij']].min(axis=1)
#     494         r['u_pax'] = r['u_i'] + r['u_j']
# --> 495         check_me_FIFO() if check else None
#     496
#     497     _inData.sblts.FIFO2 = r.copy()
#
# ~/Documents/GitHub/ExMAS/ExMAS/main.py in check_me_FIFO()
#     357             _inData.logger.warning(r[~(r.u_i <= utility_ns_i() * 1.01)])  # do we have positive sharing utility
#     358             _inData.logger.warning(r[~(r.u_j <= utility_ns_j() * 1.01)])  # do we have positive sharing utility
# --> 359             assert (r.t_i - r.ttrav_i > -3).all()  # share time is not smaller than direct
#     360             assert (r.t_j - r.ttrav_j > -3).all()
#     361             assert (abs(r.delay_i) <= r.delta_i).all()  # is the delay within bounds
#
# AssertionError:

# %% [markdown]
# ### results:
# > illustrative example of 100 rides
#
# KPIs

# %%
KPIs = inData.sblts.res.to_frame()
KPIs['description']  = ExMAS.utils.KPIs_descriptions
KPIs.columns = ['KPI', 'description']
KPIs

# %% [markdown]
#  all feasible rides

# %% [markdown]
# ---
# (c) Rafał Kucharski, Delft, 2020
