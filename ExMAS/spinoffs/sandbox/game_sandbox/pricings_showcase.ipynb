# %% [markdown]
# ## ExMAS
# > Equilibrium matching

# %%
import os
import math
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
cwd = os.getcwd()
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display
pd.options.display.max_columns = None

# %%
os.chdir(os.path.join(cwd,'../../..'))
import ExMAS.main
import ExMAS.utils
from ExMAS.utils import inData as inData
from ExMAS.main import matching
from ExMAS.game import games, pricings, prunings, pipeline

# %%
params = ExMAS.utils.get_config('ExMAS/spinoffs/game/pipe.json') # load the default 
params.t0 = pd.to_datetime(params.t0)
params.matching_obj = 'u_pax'
inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the graph
params.nP = 50
params.simTime = 0.1
params.shared_discount = 0.3
inData = ExMAS.utils.generate_demand(inData, params)  # generate requests

# %%
from ExMAS.main import init_log
params.logger_level = 'WARNING'
inData.logger = init_log(params)

# %%
inData = ExMAS.main(inData, params, plot = False)
KPIs = inData.sblts.res.to_frame('u_pax')

# %%
params.time_cost = params.VoT # travellers' cost per travel time
params.wait_cost = params.time_cost*1.5 # and waiting
params.sharing_penalty_fixed = 0 # fixed penalty (EUR) per 
params.sharing_penalty_multiplier = 0.2 # fixed penalty (EUR) per 

params.veh_cost = 2.3*params.VoT/params.avg_speed # operating costs per kilometer
params.fixed_ride_cost = 0.5 # ride fixed costs (per vehicle)

# %%
inData = games.prepare_PoA(inData)
# Out:
# 12-05-22 11:45:18-WARNING-Prepare for game:  1/6
# 12-05-22 11:45:18-WARNING-Prepare for game:  2/6
# 12-05-22 11:45:18-WARNING-Prepare for game:  3/6
# 12-05-22 11:45:18-WARNING-Prepare for game:  4/6
# 12-05-22 11:45:18-WARNING-Prepare for game:  5/6
# 12-05-22 11:45:18-WARNING-Prepare for game:  6/6

# %% [markdown]
# ### pricings with various strategies

# %%
PRICING = 'UNIFORM'

# %%
inData = ExMAS.game.pricings.update_costs(inData, params)
inData = pricings.uniform_split(inData) 
inData = pricings.externality_split(inData) 
inData = pricings.residual_split(inData) 
inData = pricings.subgroup_split(inData)

# %%
PRUNINGS = dict()  # algorithms to apply and their names
PRUNINGS['TSE'] = prunings.algo_TSE
for PRUNING, pruning in PRUNINGS.items():
    inData = pruning(inData, price_column=PRICING)  # apply pruning strategies for a given pricing strategy

# %%
ret = dict()
params.logger_level = 'INFO'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    inData = pipeline.single_eval(inData, params,
                                 EXPERIMENT_NAME='jupyter',
                                 MATCHING_OBJS=['total_group_cost'],  # this can be more
                                 PRUNINGS=["TSE"],  # and this can be more
                                 PRICING=PRICING,  # this is taken from first level loop
                                 minmax=('min', 'max'), store_res = False)  # direction BPoA, WPoA
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['matched'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','matched', 'obj']].copy()
pd.DataFrame(ret).T
# Out:
# 12-05-22 11:47:40-WARNING-Prunings:  ['TSE']
# 12-05-22 11:47:40-WARNING-Pruned nRides 169/169
# 12-05-22 11:47:40-WARNING-Mutually exclusives 0
# 12-05-22 11:47:40-WARNING-Experiment-jupyter_Pricing-UNIFORM_Objective-['total_group_cost']_Pruning-['TSE']_minmax-min
# 12-05-22 11:47:40-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:40-WARNING-Experiment-jupyter_Pricing-UNIFORM_Objective-['total_group_cost']_Pruning-['TSE']_minmax-max
# 12-05-22 11:47:40-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:40-WARNING-Prunings:  ['TSE']
# 12-05-22 11:47:40-WARNING-Pruned nRides 169/169
# 12-05-22 11:47:40-WARNING-Mutually exclusives 0
# 12-05-22 11:47:40-WARNING-Experiment-jupyter_Pricing-EXTERNALITY_Objective-['total_group_cost']_Pruning-['TSE']_minmax-min
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:41-WARNING-Experiment-jupyter_Pricing-EXTERNALITY_Objective-['total_group_cost']_Pruning-['TSE']_minmax-max
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:41-WARNING-Prunings:  ['TSE']
# 12-05-22 11:47:41-WARNING-Pruned nRides 169/169
# 12-05-22 11:47:41-WARNING-Mutually exclusives 0
# 12-05-22 11:47:41-WARNING-Experiment-jupyter_Pricing-RESIDUAL_Objective-['total_group_cost']_Pruning-['TSE']_minmax-min
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:41-WARNING-Experiment-jupyter_Pricing-RESIDUAL_Objective-['total_group_cost']_Pruning-['TSE']_minmax-max
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:41-WARNING-Prunings:  ['TSE']
# 12-05-22 11:47:41-WARNING-Pruned nRides 169/169
# 12-05-22 11:47:41-WARNING-Mutually exclusives 0
# 12-05-22 11:47:41-WARNING-Experiment-jupyter_Pricing-SUBGROUP_Objective-['total_group_cost']_Pruning-['TSE']_minmax-min
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
# 12-05-22 11:47:41-WARNING-Experiment-jupyter_Pricing-SUBGROUP_Objective-['total_group_cost']_Pruning-['TSE']_minmax-max
# 12-05-22 11:47:41-INFO-DotMap(VehHourTrav=15432, VehHourTrav_ns=16080, PassHourTrav=17645, PassHourTrav_ns=16080, PassUtility=230.12529999999995, PassUtility_ns=249.53250000000003, mean_lambda=0.3553766532489937, revenue_s=16884.0, revenue_ns=24120.0, Fare_Discount=-0.3, nR=50, SINGLE=46, PAIRS=2, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.07999999999999996, fleet_size_nonshared=40.0, fleet_size_shared=38.0, lambda_shared=0.9120301341913207)
#             VehHourTrav PassHourTrav shared_ratio costs_veh costs_user  \
# UNIFORM           15432        17645         0.08  148.4691    59.0198
# EXTERNALITY       15432        17645         0.08  148.4691    59.0198
# RESIDUAL          15432        17645         0.08  148.4691    59.0198
# SUBGROUP          15432        17645         0.08  148.4691    59.0198
#
#             matched       obj
# UNIFORM          48  207.4889
# EXTERNALITY      48  207.4889
# RESIDUAL         48   -3.2351
# SUBGROUP         48  207.4889

# %% [markdown]
# # Differences between algorithms and pricings

# %% [markdown]
# ## TNE

# %%
ret = dict()
params.logger_level = 'INFO'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    #inData = pipeline.single_eval(inData, params, prunings.algo_TNE, PRICING = PRICING, ALGO = 'TNE', minmax = ['min'], store_res = False)
    inData = pipeline.single_eval(inData, params,
                                 EXPERIMENT_NAME='jupyter',
                                 MATCHING_OBJS=['total_group_cost'],  # this can be more
                                 PRUNINGS=[prunings.algo_TNE],  # and this can be more
                                 PRICING=PRICING,  # this is taken from first level loop
                                 minmax=('min'), store_res = False)  # direction BPoA, WPoA
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['pruned'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','pruned', 'obj']]
pd.DataFrame(ret).T
# Out:
# 12-05-22 11:49:20-WARNING-Prunings:  [<function algo_TNE at 0x7f97d3914280>]
# 12-05-22 11:49:20-WARNING-Pruned nRides 169/169
# 12-05-22 11:49:20-WARNING-Mutually exclusives 0
# 12-05-22 11:49:20-WARNING-Experiment-jupyter_Pricing-UNIFORM_Objective-['total_group_cost']_Pruning-[<function algo_TNE at 0x7f97d3914280>]_minmax-m
# 12-05-22 11:49:20-INFO-Matching 50 trips to 169 rides in order to m total_group_cost
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [25], in <cell line: 4>()
#       3 inData.logger = init_log(params)
#       4 for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
#       5     #inData = pipeline.single_eval(inData, params, prunings.algo_TNE, PRICING = PRICING, ALGO = 'TNE', minmax = ['min'], store_res = False)
# ----> 6     inData = pipeline.single_eval(inData, params,
#       7                                  EXPERIMENT_NAME='jupyter',
#       8                                  MATCHING_OBJS=['total_group_cost'],  # this can be more
#       9                                  PRUNINGS=[prunings.algo_TNE],  # and this can be more
#      10                                  PRICING=PRICING,  # this is taken from first level loop
#      11                                  minmax=('min'), store_res = False)  # direction BPoA, WPoA
#      12     inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
#      13     inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
#
# File ~/PycharmProjects/ExMAS/ExMAS/game/pipeline.py:73, in single_eval(inData, params, EXPERIMENT_NAME, MATCHING_OBJS, PRUNINGS, PRICING, minmax, store_res)
#      71 inData.logger.warning(res_name)
#      72 if 'TSE' not in PRUNINGS:
# ---> 73     inData = matching(inData, params, make_assertion=False)  # < - main matching
#      74 else:
#      75     inData = prunings.algo_TSE(inData,
#      76                                params.matching_obj)  # here we do not do ILP, but heuristical algorithm
#
# File ~/PycharmProjects/ExMAS/ExMAS/main.py:811, in matching(_inData, params, plot, make_assertion)
#     808 # over separate platforms
#     810 if not multi_platform_matching: # classic matching for single platform
# --> 811     selected = match(im=rides, r=requests, params=params, plot=plot,
#     812                      make_assertion=make_assertion, logger = _inData.logger,
#     813                      mutually_exclusives = _inData.sblts.get('mutually_exclusives', []))
#     814     rides['selected'] = pd.Series(selected)
#     816 else:  # matching to multiple platforms
#     817     # select only rides for which all travellers are assigned to this platform
#
# File ~/PycharmProjects/ExMAS/ExMAS/main.py:958, in match(im, r, params, plot, make_assertion, logger, mutually_exclusives)
#     955 else:
#     956     costs = im[cost_col]  # set the costs
# --> 958 prob += pulp.lpSum([variables[i] * costs[i] for i in variables]), 'ObjectiveFun'  # ffef
#     960 j = 0  # adding constrains
#     961 for imr in m:
#
# UnboundLocalError: local variable 'prob' referenced before assignment

# %% [markdown]
# ## Hermetic

# %%
ret = dict()
params.logger_level = 'WARNING'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    inData = pipeline.single_eval(inData, params, prunings.algo_HERMETIC, PRICING = PRICING, ALGO = 'HERMETIC', minmax = ['min'], store_res = False)
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['pruned'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','pruned', 'obj']]
pd.DataFrame(ret).T
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 4>()
#       3 inData.logger = init_log(params)
#       4 for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
# ----> 5     inData = pipeline.single_eval(inData, params, prunings.algo_HERMETIC, PRICING = PRICING, ALGO = 'HERMETIC', minmax = ['min'], store_res = False)
#       6     inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
#       7     inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
#
# TypeError: single_eval() got an unexpected keyword argument 'ALGO'

# %% [markdown]
# ## RUE

# %%
ret = dict()
params.logger_level = 'INFO'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    inData = pipeline.single_eval(inData, params, prunings.algo_RUE, PRICING = PRICING, ALGO = 'RUE', minmax = ['min'], store_res = False)
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['pruned'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','pruned', 'obj']]
pd.DataFrame(ret).T
# Out:
# 15-12-20 16:21:21-INFO-Mergeable groups: 25-30
# 15-12-20 16:21:22-INFO-Mergeable groups: 5-88
# 15-12-20 16:21:22-INFO-Mergeable groups: 47-148
# 15-12-20 16:21:22-WARNING-Pruned nRides 222/222
# 15-12-20 16:21:22-WARNING-UNIFORM-RUE-UNIFORM-min
# 15-12-20 16:21:22-INFO-Matching 50 trips to 222 rides in order to min UNIFORM
# 15-12-20 16:21:22-INFO-Adding 3 mutually exlcusive constrains
# 15-12-20 16:21:22-INFO-Problem solution: Optimal.
# Total costs for single trips:            162
# reduced by matching to:                  159
# 15-12-20 16:21:22-INFO-DotMap(VehHourTrav=15108, VehHourTrav_ns=17058, PassHourTrav=17711, PassHourTrav_ns=17058, PassUtility=253.51685, PassUtility_ns=264.633, mean_lambda=0.30019524894240157, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=36, PAIRS=7, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.28, fleet_size_nonshared=45.0, fleet_size_shared=38.0, lambda_shared=0.30019524894240157)
# 15-12-20 16:21:22-INFO-Mergeable groups: 10-22
# 15-12-20 16:21:22-INFO-Mergeable groups: 5-39
# 15-12-20 16:21:22-INFO-Mergeable groups: 25-30
# 15-12-20 16:21:23-INFO-Mergeable groups: 35-42
# 15-12-20 16:21:23-INFO-Mergeable groups: 0-36
# 15-12-20 16:21:23-INFO-Mergeable groups: 39-40
PAIRS=7, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.28, fleet_size_nonshared=45.0, fleet_size_shared=38.0, lambda_shared=0.30019524894240157)
# 15-12-20 16:21:27-WARNING-Pruned nRides 222/222
# 15-12-20 16:21:27-WARNING-SUBGROUP-RUE-SUBGROUP-min
# 15-12-20 16:21:27-INFO-Matching 50 trips to 222 rides in order to min SUBGROUP
# 15-12-20 16:21:27-INFO-Problem solution: Optimal.
# Total costs for single trips:            162
# reduced by matching to:                  162
# 15-12-20 16:21:27-INFO-DotMap(VehHourTrav=15815, VehHourTrav_ns=17058, PassHourTrav=19702, PassHourTrav_ns=17058, PassUtility=253.4155, PassUtility_ns=264.633, mean_lambda=0.06940017386264852, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=12, PAIRS=19, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.76, fleet_size_nonshared=45.0, fleet_size_shared=27.0, lambda_shared=0.06940017386264852)
#             VehHourTrav PassHourTrav shared_ratio costs_veh costs_user pruned  \
# UNIFORM           15108        17711         0.28   90.7192    68.9161     43
# EXTERNALITY       15108        17711         0.28   90.7192    68.9161     43
# RESIDUAL          15108        17711         0.28   90.7192    68.9161     43
# SUBGROUP          15815        19702         0.76    88.755    100.877     31
#
#                  obj
# UNIFORM      159.635
# EXTERNALITY  159.635
# RESIDUAL     -2.6817
# SUBGROUP     162.314

# %% [markdown]
# ## RSIE

# %%
ret = dict()
params.logger_level = 'INFO'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    inData = pipeline.single_eval(inData, params, prunings.algo_RSIE, PRICING = PRICING, ALGO = 'RSIE', minmax = ['min'], store_res = False)
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['pruned'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','pruned', 'obj']]
pd.DataFrame(ret).T
# Out:
# 15-12-20 16:21:27-WARNING-Searching unstable pairs 0/222. 0 found so far
# 15-12-20 16:21:36-WARNING-Searching unstable pairs 20/222. 96 found so far
# 15-12-20 16:21:44-WARNING-Searching unstable pairs 40/222. 157 found so far
# 15-12-20 16:21:51-WARNING-Searching unstable pairs 60/222. 186 found so far
# 15-12-20 16:21:56-WARNING-Searching unstable pairs 80/222. 193 found so far
# 15-12-20 16:22:01-WARNING-Searching unstable pairs 100/222. 205 found so far
# 15-12-20 16:22:06-WARNING-Searching unstable pairs 120/222. 205 found so far
# 15-12-20 16:22:10-WARNING-Searching unstable pairs 140/222. 210 found so far
# 15-12-20 16:22:15-WARNING-Searching unstable pairs 160/222. 239 found so far
# 15-12-20 16:22:19-WARNING-Searching unstable pairs 180/222. 239 found so far
# 15-12-20 16:22:24-WARNING-Searching unstable pairs 200/222. 240 found so far
# 15-12-20 16:22:28-WARNING-Searching unstable pairs 220/222. 240 found so far
# 15-12-20 16:22:28-WARNING-Pruned nRides 222/222
# 15-12-20 16:22:28-WARNING-UNIFORM-RSIE-UNIFORM-min
# 15-12-20 16:22:28-INFO-Matching 50 trips to 222 rides in order to min UNIFORM
# 15-12-20 16:22:28-INFO-Adding 240 mutually exlcusive constrains
# 15-12-20 16:22:28-INFO-Problem solution: Optimal.
# Total costs for single trips:            162
# reduced by matching to:                  159
# 15-12-20 16:22:28-INFO-DotMap(VehHourTrav=15108, VehHourTrav_ns=17058, PassHourTrav=17711, PassHourTrav_ns=17058, PassUtility=253.51685, PassUtility_ns=264.633, mean_lambda=0.30019524894240157, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE
# 15-12-20 16:24:26-WARNING-Searching unstable pairs 220/222. 219 found so far
# 15-12-20 16:24:26-WARNING-Pruned nRides 222/222
# 15-12-20 16:24:26-WARNING-RESIDUAL-RSIE-RESIDUAL-min
# 15-12-20 16:24:26-INFO-Matching 50 trips to 222 rides in order to min RESIDUAL
# 15-12-20 16:24:26-INFO-Adding 219 mutually exlcusive constrains
# 15-12-20 16:24:27-INFO-Problem solution: Optimal.
# Total costs for single trips:              0
# reduced by matching to:                   -2
# 15-12-20 16:24:27-INFO-DotMap(VehHourTrav=15108, VehHourTrav_ns=17058, PassHourTrav=17711, PassHourTrav_ns=17058, PassUtility=253.51685, PassUtility_ns=264.633, mean_lambda=0.30019524894240157, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=36, PAIRS=7, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.28, fleet_size_nonshared=45.0, fleet_size_shared=38.0, lambda_shared=0.30019524894240157)
# 15-12-20 16:24:27-WARNING-Searching unstable pairs 0/222. 0 found so far
# 15-12-20 16:24:34-WARNING-Searching unstable pairs 20/222. 399 found so far
# 15-12-20 16:24:41-WARNING-Searching unstable pairs 40/222. 876 found so far
# 15-12-20 16:24:47-WARNING-Searching unstable pairs 60/222. 1138 found so far
# 15-12-20 16:24:51-WARNING-Searching unstable pairs 80/222. 1161 found so far
# 15-12-20 16:24:56-WARNING-Searching unstable pairs 100/222. 1176 found so far
# 15-12-20 16:25:01-WARNING-Searching unstable pairs 120/222. 1223 found so far
# 15-12-20 16:25:05-WARNING-Searching unstable pairs 140/222. 1234 found so far
# 15-12-20 16:25:10-WARNING-Searching unstable pairs 160/222. 1264 found so far
# 15-12-20 16:25:14-WARNING-Searching unstable pairs 180/222. 1284 found so far
# 15-12-20 16:25:19-WARNING-Searching unstable pairs 200/222. 1286 found so far
# 15-12-20 16:25:24-WARNING-Searching unstable pairs 220/222. 1286 found so far
# 15-12-20 16:25:24-WARNING-Pruned nRides 222/222
# 15-12-20 16:25:24-WARNING-SUBGROUP-RSIE-SUBGROUP-min
# 15-12-20 16:25:25-INFO-Matching 50 trips to 222 rides in order to min SUBGROUP
# 15-12-20 16:25:25-INFO-Adding 1286 mutually exlcusive constrains
# 15-12-20 16:25:25-INFO-Problem solution: Optimal.
# Total costs for single trips:            162
# reduced by matching to:                  162
# 15-12-20 16:25:25-INFO-DotMap(VehHourTrav=15197, VehHourTrav_ns=17058, PassHourTrav=19623, PassHourTrav_ns=17058, PassUtility=248.87515, PassUtility_ns=264.633, mean_lambda=0.1106307583274273, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=10, PAIRS=20, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.8, fleet_size_nonshared=45.0, fleet_size_shared=27.0, lambda_shared=0.1106307583274273)
#             VehHourTrav PassHourTrav shared_ratio costs_veh costs_user pruned  \
# UNIFORM           15108        17711         0.28   90.7192    68.9161     43
# EXTERNALITY       15108        17711         0.28   90.7192    68.9161     43
# RESIDUAL          15108        17711         0.28   90.7192    68.9161     43
# SUBGROUP          15197        19623          0.8   85.5113    95.9004     30
#
#                  obj
# UNIFORM      159.635
# EXTERNALITY  159.635
# RESIDUAL     -2.6817
# SUBGROUP     162.314

# %% [markdown]
# ## TSE

# %%
ret = dict()
params.logger_level = 'INFO'
inData.logger = init_log(params)
for PRICING in ['UNIFORM','EXTERNALITY','RESIDUAL','SUBGROUP']:
    inData = pipeline.single_eval(inData, params, prunings.algo_TSE, PRICING = PRICING, ALGO = 'TSE', minmax = ['min'], store_res = False)
    inData.sblts.res['costs_veh'] = inData.sblts.rides[inData.sblts.rides.selected==1]['costs_veh'].sum()
    inData.sblts.res['obj'] = inData.sblts.rides[inData.sblts.rides.selected==1][PRICING].sum()
    inData.sblts.res['costs_user'] = inData.sblts.rides[inData.sblts.rides.selected==1][ 'costs_user'].sum()
    inData.sblts.res['pruned'] = inData.sblts.rides[inData.sblts.rides.selected==1].shape[0]
    ret[PRICING] = inData.sblts.res.loc[['VehHourTrav','PassHourTrav','shared_ratio','costs_veh', 'costs_user','pruned', 'obj']]
pd.DataFrame(ret).T
# Out:
# 15-12-20 16:25:26-WARNING-Pruned nRides 222/222
# 15-12-20 16:25:26-INFO-DotMap(VehHourTrav=16748, VehHourTrav_ns=17058, PassHourTrav=19623, PassHourTrav_ns=17058, PassUtility=248.87515, PassUtility_ns=264.633, mean_lambda=0.30825496342737724, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=48, PAIRS=1, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.040000000000000036, fleet_size_nonshared=45.0, fleet_size_shared=44.0, lambda_shared=0.953082919914954)
# 15-12-20 16:25:26-WARNING-Pruned nRides 222/222
# 15-12-20 16:25:26-INFO-DotMap(VehHourTrav=16748, VehHourTrav_ns=17058, PassHourTrav=19623, PassHourTrav_ns=17058, PassUtility=248.87515, PassUtility_ns=264.633, mean_lambda=0.30825496342737724, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=48, PAIRS=1, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.040000000000000036, fleet_size_nonshared=45.0, fleet_size_shared=44.0, lambda_shared=0.953082919914954)
# 15-12-20 16:25:27-WARNING-Pruned nRides 222/222
# 15-12-20 16:25:27-INFO-DotMap(VehHourTrav=15108, VehHourTrav_ns=17058, PassHourTrav=19623, PassHourTrav_ns=17058, PassUtility=248.87515, PassUtility_ns=264.633, mean_lambda=0.30019524894240157, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=36, PAIRS=7, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.28, fleet_size_nonshared=45.0, fleet_size_shared=38.0, lambda_shared=0.6951807228915663)
# 15-12-20 16:25:27-WARNING-Pruned nRides 222/222
# 15-12-20 16:25:27-INFO-DotMap(VehHourTrav=17058, VehHourTrav_ns=17058, PassHourTrav=19623, PassHourTrav_ns=17058, PassUtility=248.87515, PassUtility_ns=264.633, mean_lambda=nan, revenue_s=17910.899999999998, revenue_ns=25587.0, Fare_Discount=-0.3000000000000001, nR=50, SINGLE=50, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=45.0, fleet_size_shared=45.0, lambda_shared=0)
#             VehHourTrav PassHourTrav shared_ratio costs_veh costs_user pruned  \
# UNIFORM           16748        19623         0.04   100.772    61.3221     49
# EXTERNALITY       16748        19623         0.04   100.772    61.3221     49
# RESIDUAL          15108        19623         0.28   90.7192    68.9161     43
# SUBGROUP          17058        19623            0   102.614     59.703     50
#
#                  obj
# UNIFORM      162.094
# EXTERNALITY  162.094
# RESIDUAL     -2.6817
# SUBGROUP     162.314

# %% [markdown]
# ---
# (c) Rafał Kucharski, Delft, 2020
